# %% [markdown]
# ## Installing D-Tale

# %%
# Install dtale
# !pip install dtale
# Out:
# ...
#   Obtaining dependency information for dtale from https://files.pythonhosted.org/packages/c1/c3/766dc62ec7002289209c565638fb84120c420937157d24515b4575b1c7ac/dtale-3.9.0-py2.py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 146.6 kB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 490.2 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Obtaining dependency information for Flask-Compress from https://files.pythonhosted.org/packages/3f/d2/23fd656d38d4c896fa14371990b9978722c48a30d0edcf6b5f7054775a07/Flask_Compress-1.14-py3-none-any.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 477.8 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 219.7/219.7 kB 638.0 kB/s eta 0:00:00a 0:00:01
# ...

# %% [markdown]
# ## Importing Libraries

# %%
import dtale
import pandas as pd

# %% [markdown]
# ## Loading Dataset and opening Interactive window

# %%
# Load your dataset with specified encoding
df = pd.read_csv('/Users/kishoreu/Desktop/KN - EDA/Zomatodataset/zomato.csv', encoding='latin-1')

# Use dtale to create an interactive web-based interface
dtale.show(df,enable_custom_filters=True)
# Out:
# 2024-01-13 15:38:13,325 - WARNING  - Custom filtering enabled. Custom filters are vulnerable to code injection attacks, please only use in trusted environments.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Laptop-K.local:40000/dtale/iframe/11"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## Opening Interactive HTML Page in Browser

# %%
# Create interactive charts with dtale
d=dtale.show(df)
d.open_browser()

# %% [markdown]
# ## Creating output for Descriptive Statistics

# %%
# Generate descriptive statistics using dtale
df.describe(include='all')
# Out:
#         Restaurant ID  Restaurant Name  Country Code       City  \
# count    9.551000e+03             9551   9551.000000       9551
# unique            NaN             7446           NaN        141
# top               NaN  Cafe Coffee Day           NaN  New Delhi
# freq              NaN               83           NaN       5473
# mean     9.051128e+06              NaN     18.365616        NaN
# std      8.791521e+06              NaN     56.750546        NaN
# min      5.300000e+01              NaN      1.000000        NaN
# 25%      3.019625e+05              NaN      1.000000        NaN
# 50%      6.004089e+06              NaN      1.000000        NaN
# 75%      1.835229e+07              NaN      1.000000        NaN
# max      1.850065e+07              NaN    216.000000        NaN
#
#                            Address         Locality  \
# count                         9551             9551
# unique                        8918             1208
# ...
